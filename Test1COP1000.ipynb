# %% [markdown]
# # Introduction to Programming

# %%
# https://numpy.org/doc/stable/reference/arrays.dtypes.html#arrays-dtypes
# https://www.edureka.co/blog/python-libraries/ 
# https://wiki.python.org/moin/UsefulModules
# https://technovationchallenge.org/curriculum/coding-2/
# https://www.unf.edu/~broggio/cop2221/2221pseu.htm
# https://study.com/academy/lesson/what-is-an-algorithm-definition-examples.html

# %% [markdown]
# **COURSE STRUCTURE**
#
# 1. **Course Introduction**
#      * Course Introduction
#      * Intro to Programming
#      * Intro to the Python Language
#      * Downloading and installing the IDLE
#        * Jupyter Notebook
#
# 2. **Program Development Steps & Algorithms**------Logic, Flowcharts, Psuedocode and Data Types
#      * Introduction to Flow Charts
#        * Flowcharting symbols
#        * On-Page and Off-Page Connectors
#
#      * Introduction to Algorithms
#
#      * Introduction to Pseudocode
#      * Introduction to Libraries
#        * numpy  @
#        * pyTorch (torch) @
#        * pandas  @
#        * pendulum  @
#        * scikit-learn
#        * gradio  @
#        * TensorFlow  @
#        * PyQT  @
#        * matplotlib  @
#        * Django  @
#
#
#
# 3. **Computer Data Types**
#      * **Getting the Data Type**
#          * *numpy*
#              * dtype()
#          * *py*
#              * type()
#
#      * **Boolean Data**
#           * *numpy*
#                * bool_
#      * **Machine Data**
#           * bits
#           * bytes
#           * word
#           * binary number
#      * **Text Data**
#           * **Character**
#                * *py*
#                      *
#                * *numpy*
#                    * byte
#                    * ubyte
#           * **String**
#                * *py*
#                    * str
#           * **ASCII**
#      * **Numeric Data**
#           * **Integer**
#            * *numpy*
#              * int
#              * uintc
#            * *py*
#              * int
#           * **Floating Point**
#            * *numpy*
#              * float16 (half precision point)
#              * single
#            * *py*
#              * float
#           * **Short**
#            * *numpy*
#              * short
#              * ushort
#           * **Long**
#            * *numpy*
#              * int_
#              * uint
#              * longlong
#              * ulonglong
#           * **Double**
#            * *numpy*
#              * double
#              * longdouble
#           * **Decimal**
#      * **Composite Data Types**
#           * Struct's
#           * Collections
#           * Lists
#           * Arrays
#      * **Enumerated type**
#           * Enum
#           * Factor
#
#      * **Date / Time**
#           * Date
#           * Time
#           * DateTime
#
#      * **Pointers and References**
#           * Pointers
#
#      * **Complex numbers**
#           * *numpy*
#             * csingle (two single-precision floats)
#             * cdouble (two double-precision floats)
#             * clongdouble (two extended-precision floats)
#           * *py*
#             * complex
#
# 4. **Introduction to Control Structures**
#         * Sequence, Decision and Repetition
#         * Euclids Algorithm
#         *
#
#      * Sequential Operations
#
#      * Decisions and Selection Structure
#          * Decisions: Comparison Operators
#          * Decisions: Single Selection
#          * Decisions: Dual Selection
#          * Decisions: Three or More Choices
#          * Decisions: Nested Ifs
#          * Decisions: Boolean Operators
#          * AND... OR... NOT...
#
#      * Repetition or Loops
#          * Condition-Controlled
#          * Count-Controlled
#          * for... next
#
#      * Variables
#
#      * Catching Errors
#
#
# 4.  Data Structures and Functions
#      * Python Scripts
#      * Lists
#      * Loops
#      * Functions
#
# 5. Data Structures and Functions cont'd
#     * More Lists
#     * Strings
#     * Tuples
#     * Sets
#     * PyCharm
#
# 6. Additional Structures
#     * Dictionaries
#     * Files

# %%
print('hello world')
# Out:
# hello world
